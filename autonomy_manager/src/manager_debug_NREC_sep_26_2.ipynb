# %%
# %load_ext autoreload
# %autoreload 2
    
from manager import * 
import rosnode
import time
from env_utils.algo_constants import *

# %%
if '/manager' in rosnode.get_node_names():
    # print("Manager is running")
    rosnode.kill_nodes(['manager'])
    time.sleep(1)

m = Manager(skip_checks=False, 
            debug_flag=True) 
            # fake_hardware_flags=[FAKE_ARM, FAKE_PXRF])
# m.fake_pxrf_values = [0.13, 0.2, 0.0, 0.5, 0.6, 0.05]
# m.fake_pxrf_values = [0.4, 0.2, 0.3, 0, 0.02, 0.5, 0.32, 0.0, 0.6, 0.0, 0.1, 0.0]
# Out:
# [INFO] [1727384772.622180]:  < Status: Initialization >
# [INFO] [1727384772.667815]:  < Status: Waiting for GPS init >
# [INFO] [1727384772.668790]: Waiting for GPS Initialization...
# [INFO] [1727384773.670869]: GPS Full Navigation Achieved!
# [INFO] [1727384773.673214]:  < Status: Ready >
# [INFO] [1727384773.688091]:  | Algorithm Set to ADAPTIVE with number of samples = 16
# [INFO] [1727384773.689030]:  ----------- READY -----------
# [WARN] [1727384773.686924]: Started PXRF
# [WARN] [1727384799.366349]: | Reset
# [INFO] [1727384799.434524]: ----------------
#  Boundary Points:
#  [(40.472192252948844, -79.96618878366543), (40.472287089637994, -79.96611691825605), (40.47232471460376, -79.96621370229717), (40.47222688966315, -79.96628646854616), (40.472192252948844, -79.96618878366543)]
# ----------------
# [INFO] [1727384800.216128]: Width: 15 m | 60 cells
# [INFO] [1727384800.217386]: Height: 15 m | : 60 cells
# [INFO] [1727384800.218219]: Start: (6.086766295717098, 3.375063369050622) m | (23, 12) cells
# [INFO] [1727384800.218873]: Boundary Offset (MAP): [[8.325877341558225, 0.0], [14.294671454816125, 10.598438502289355], [6.0412823701044545, 14.678791693411767], [0.0, 3.747763028368354], [8.325877341558225, 0.0]]
# [INFO] [1727384800.219547]: Boundary Offset (GRID): [(32, 0), (56, 41), (23, 57), (0, 13), (32, 0)]
# len(x1): 60, len(x2): 60, len(x1x2): (3600, 2)
# [INFO] [1727384800.245251]: lengths of x1 | x2 | x1x2: 60 | 60 | (3600, 2)
# [INFO] [1727384800.254975]:  < Status: Received search area >
# [INFO] [1727384800.319010]:  | Inital Robot Location (GPS|Map|Grid): (40.47222289871689, -79.9662147543367) | (6.084473385824822, 3.375960969366133) | (23, 12)
# [INFO] [1727384933.018523]: PXRF Mean Value: 0.0
# [INFO] [1727384933.019853]:  < Status: Finished scan >
# [INFO] [1727384933.121530]: PXRF Mean Value: 0.0
# [INFO] [1727384933.122644]:  < Status: Finished scan >
# [INFO] [1727385024.127125]: PXRF Mean Value: 0.0
# [INFO] [1727385024.128191]:  < Status: Finished scan >
# [INFO] [1727385024.234004]: PXRF Mean Value: 0.0
# [INFO] [1727385024.235267]:  < Status: Finished scan >
# [INFO] [1727385113.589316]: PXRF Mean Value: 0.0
# [INFO] [1727385113.590539]:  < Status: Finished scan >
# [INFO] [1727385113.829153]: PXRF Mean Value: 0.0
# [INFO] [1727385113.830304]:  < Status: Finished scan >
# [INFO] [1727385227.632192]: PXRF Mean Value: 0.0
# [INFO] [1727385227.633384]:  < Status: Finished scan >
# [INFO] [1727385227.749052]: PXRF Mean Value: 0.0
# [INFO] [1727385227.749966]:  < Status: Finished scan >
# [INFO] [1727385328.546463]: PXRF Mean Value: 0.0
# [INFO] [1727385328.547522]:  < Status: Finished scan >
# [INFO] [1727385328.813711]: PXRF Mean Value: 0.0
# [INFO] [1727385328.814791]:  < Status: Finished scan >
# [INFO] [1727385433.977059]: PXRF Mean Value: 0.0
# [INFO] [1727385433.978133]:  < Status: Finished scan >
# [INFO] [1727385434.095915]: PXRF Mean Value: 0.0
# [INFO] [1727385434.096934]:  < Status: Finished scan >
# [INFO] [1727385572.425257]: PXRF Mean Value: 0.0
# [INFO] [1727385572.426515]:  < Status: Finished scan >
# [INFO] [1727385572.552441]: PXRF Mean Value: 0.0
# [INFO] [1727385572.553605]:  < Status: Finished scan >
# [INFO] [1727385666.058030]: PXRF Mean Value: 0.0
# [INFO] [1727385666.059170]:  < Status: Finished scan >
# [INFO] [1727385666.161630]: PXRF Mean Value: 0.0
# [INFO] [1727385666.162455]:  < Status: Finished scan >
# [INFO] [1727385760.774850]: PXRF Mean Value: 0.0
# [INFO] [1727385760.775840]:  < Status: Finished scan >
# [INFO] [1727385760.976678]: PXRF Mean Value: 0.0
# [INFO] [1727385760.977743]:  < Status: Finished scan >
# [INFO] [1727385890.597734]: PXRF Mean Value: 0.0
# [INFO] [1727385890.598801]:  < Status: Finished scan >
# [INFO] [1727385890.700152]: PXRF Mean Value: 0.0
# [INFO] [1727385890.701118]:  < Status: Finished scan >
# [INFO] [1727386028.076754]: PXRF Mean Value: 0.0
# [INFO] [1727386028.078007]:  < Status: Finished scan >
# [INFO] [1727386028.262787]: PXRF Mean Value: 0.0
# [INFO] [1727386028.263900]:  < Status: Finished scan >
# [INFO] [1727386210.575289]: PXRF Mean Value: 0.0
# [INFO] [1727386210.576349]:  < Status: Finished scan >
# [INFO] [1727386210.676610]: PXRF Mean Value: 0.0
# [INFO] [1727386210.677581]:  < Status: Finished scan >

# %%
if (m.status != SCANNING and
    m.status != ERROR):
    while ( m.status == ARRIVED_AT_SCAN_LOC or
            m.status == ARM_RETURNED):
            m.run_once()
    m.run_once()
    print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')

print(m.status)
# Out:
# [INFO] [1727384044.732788]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727384044.733923]:  < Status: Running search algo >
# [INFO] [1727384044.811826]:  | Updating GPR with value=0.06572749465703964 at (GPS|Map|Grid): (40.47225386177974, -79.96615483888145) | (11.126268539926969, 6.87256386410445) | (43, 26)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 5.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1727384045.631302]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.472227336831814, -79.966208309954) | (6.625, 3.875) | [26, 15]
# [INFO] [1727384045.714905]:  < Status: Received next scan loc >
# [INFO] [1727384045.715892]: ----------- Manager Loop END -----------
# [INFO] [1727384045.717568]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727384045.718613]:  < Status: Navigating to scan loc >
# [INFO] [1727384045.726261]:  | Goal Sent to movebase...

# %%
for i in range(0,6):
    # print(f" ----- PATH LENGTH: {m.adaptiveROS.path_len} -----")
    
    while (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()
        print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
    
    while (m.status == SCANNING):
        rospy.sleep(2)
        
    print(m.status)
# Out:
# [INFO] [1727385456.422027]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385456.423009]:  < Status: Arm returning >
# [INFO] [1727385465.994904]:  < Status: Arm returned >
# [INFO] [1727385465.996134]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.78e+05)
# [INFO] [1727385465.997910]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385465.998977]:  < Status: Running search algo >
# [INFO] [1727385466.070647]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.47230567429411, -79.96618095879593) | (8.838211177033372, 12.597476395778358) | (34, 49)
# ---------
# [INFO] [1727385466.826874]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.472285121274794, -79.96612189910111) | (13.875, 10.375) | [55, 41]
# [INFO] [1727385466.859184]:  < Status: Received next scan loc >
# [INFO] [1727385466.860183]: ----------- Manager Loop END -----------
# [INFO] [1727385466.861814]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385466.862720]:  < Status: Navigating to scan loc >
# [INFO] [1727385466.869712]:  | Goal Sent to movebase...
# [INFO] [1727385507.920845]:  | Movebase Goal Reached, Backing up...
# [INFO] [1727385509.925162]:  < Status: Arrived at scan loc >
# [INFO] [1727385509.926724]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=5.54e+05)
# [INFO] [1727385509.928164]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385509.929081]:  < Status: Arm lowering >
# [INFO] [1727385523.988615]:  < Status: Arm lowered >
# [INFO] [1727385523.989777]: ----------- Manager Loop END -----------
# [INFO] [1727385523.991318]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385523.992276]:  < Status: Scanning >
# [INFO] [1727385523.993143]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=5.54e+05)
# Finished scan
# [INFO] [1727385574.041071]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385574.042299]:  < Status: Arm returning >
# [INFO] [1727385583.605116]:  < Status: Arm returned >
# [INFO] [1727385583.606480]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=5.54e+05)
# [INFO] [1727385583.607950]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385583.608904]:  < Status: Running search algo >
# [INFO] [1727385583.680835]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.472292902529304, -79.96612515614561) | (13.588779865182005, 11.235502110794187) | (53, 43)
# ---------
# [INFO] [1727385584.463734]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.472267211595025, -79.96613397030012) | (12.875, 8.375) | [51, 33]
# [INFO] [1727385584.497732]:  < Status: Received next scan loc >
# [INFO] [1727385584.498705]: ----------- Manager Loop END -----------
# [INFO] [1727385584.500206]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385584.501222]:  < Status: Navigating to scan loc >
# [INFO] [1727385584.508165]:  | Goal Sent to movebase...
# [INFO] [1727385601.159258]:  | Movebase Goal Reached, Backing up...
# [INFO] [1727385603.163631]:  < Status: Arrived at scan loc >
# [INFO] [1727385603.164855]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.42e+05)
# [INFO] [1727385603.166282]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385603.167170]:  < Status: Arm lowering >
# [INFO] [1727385617.219275]:  < Status: Arm lowered >
# [INFO] [1727385617.220405]: ----------- Manager Loop END -----------
# [INFO] [1727385617.221823]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385617.222739]:  < Status: Scanning >
# [INFO] [1727385617.223647]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.42e+05)
# Finished scan
# [INFO] [1727385667.264506]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385667.298891]:  < Status: Arm returning >
# [INFO] [1727385676.837574]:  < Status: Arm returned >
# [INFO] [1727385676.838878]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.42e+05)
# [INFO] [1727385676.840521]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385676.841463]:  < Status: Running search algo >
# [INFO] [1727385676.905156]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.472263776469646, -79.96614334803215) | (12.084507223102264, 7.984381844289601) | (47, 30)
# ---------
# [INFO] [1727385677.750256]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.472285121274794, -79.96612189910111) | (13.875, 10.375) | [55, 41]
# [INFO] [1727385677.783740]:  < Status: Received next scan loc >
# [INFO] [1727385677.784726]: ----------- Manager Loop END -----------
# [INFO] [1727385677.786193]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385677.787081]:  < Status: Navigating to scan loc >
# [INFO] [1727385677.794553]:  | Goal Sent to movebase...
# [INFO] [1727385696.345482]:  | Movebase Goal Reached, Backing up...
# [INFO] [1727385698.349520]:  < Status: Arrived at scan loc >
# [INFO] [1727385698.350938]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.88e+05)
# [INFO] [1727385698.352493]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385698.353374]:  < Status: Arm lowering >
# [INFO] [1727385712.419894]:  < Status: Arm lowered >
# [INFO] [1727385712.421170]: ----------- Manager Loop END -----------
# [INFO] [1727385712.422714]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385712.423639]:  < Status: Scanning >
# [INFO] [1727385712.424523]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.88e+05)
# Finished scan
# [INFO] [1727385762.472459]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385762.473445]:  < Status: Arm returning >
# [INFO] [1727385772.027330]:  < Status: Arm returned >
# [INFO] [1727385772.029462]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.88e+05)
# [INFO] [1727385772.030876]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385772.031775]:  < Status: Running search algo >
# [INFO] [1727385772.094939]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.47227932672706, -79.96612533820219) | (13.590998527011834, 9.728377577848732) | (53, 37)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:429: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified upper bound 1000000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1727385772.836031]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47219565199078, -79.96619110117953) | (8.125, 0.375) | [32, 1]
# [INFO] [1727385772.867204]:  < Status: Received next scan loc >
# [INFO] [1727385772.868297]: ----------- Manager Loop END -----------
# [INFO] [1727385772.869972]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385772.871029]:  < Status: Navigating to scan loc >
# [INFO] [1727385772.878759]:  | Goal Sent to movebase...
# [INFO] [1727385825.580016]:  | Movebase Goal Reached, Backing up...
# [INFO] [1727385827.584645]:  < Status: Arrived at scan loc >
# [INFO] [1727385827.585805]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=1e+06)
# [INFO] [1727385827.587295]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385827.588127]:  < Status: Arm lowering >
# [INFO] [1727385841.656835]:  < Status: Arm lowered >
# [INFO] [1727385841.658334]: ----------- Manager Loop END -----------
# [INFO] [1727385841.660469]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385841.661737]:  < Status: Scanning >
# [INFO] [1727385841.662750]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=1e+06)
# Finished scan
# [INFO] [1727385891.710351]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385891.711399]:  < Status: Arm returning >
# [INFO] [1727385901.309745]:  < Status: Arm returned >
# [INFO] [1727385901.310976]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=1e+06)
# [INFO] [1727385901.312479]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385901.313339]:  < Status: Running search algo >
# [INFO] [1727385901.379691]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.472191780801175, -79.96619567185067) | (7.7428030704613775, -0.061534793116152287) | (29, 0)
# ---------
# [INFO] [1727385902.184432]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.472285121274794, -79.96612189910111) | (13.875, 10.375) | [55, 41]
# [INFO] [1727385902.217437]:  < Status: Received next scan loc >
# [INFO] [1727385902.218560]: ----------- Manager Loop END -----------
# [INFO] [1727385902.220058]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385902.221022]:  < Status: Navigating to scan loc >
# [INFO] [1727385902.228301]:  | Goal Sent to movebase...
# [INFO] [1727385963.279506]:  | Movebase Goal Reached, Backing up...
# [INFO] [1727385965.284093]:  < Status: Arrived at scan loc >
# [INFO] [1727385965.285486]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=8.71e+05)
# [INFO] [1727385965.286980]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385965.287751]:  < Status: Arm lowering >
# [INFO] [1727385979.343189]:  < Status: Arm lowered >
# [INFO] [1727385979.344351]: ----------- Manager Loop END -----------
# [INFO] [1727385979.345691]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727385979.346774]:  < Status: Scanning >
# [INFO] [1727385979.347726]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=8.71e+05)
# Finished scan
# [INFO] [1727386029.390305]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727386029.391608]:  < Status: Arm returning >
# [INFO] [1727386038.984580]:  < Status: Arm returned >
# [INFO] [1727386038.986010]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=8.71e+05)
# [INFO] [1727386038.987656]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727386038.988800]:  < Status: Running search algo >
# [INFO] [1727386039.060882]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.47227649019353, -79.96613304212904) | (12.943045001011342, 9.404765690676868) | (50, 36)
# ---------
# [INFO] [1727386039.794322]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47222349240368, -79.96628209696308) | (0.375, 3.375) | [1, 13]
# [INFO] [1727386039.829188]:  < Status: Received next scan loc >
# [INFO] [1727386039.830148]: ----------- Manager Loop END -----------
# [INFO] [1727386039.831736]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727386039.832701]:  < Status: Navigating to scan loc >
# [INFO] [1727386039.840252]:  | Goal Sent to movebase...
# [INFO] [1727386145.641123]:  | Movebase Goal Reached, Backing up...
# [INFO] [1727386147.645431]:  < Status: Arrived at scan loc >
# [INFO] [1727386147.646580]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.81e+05)
# [INFO] [1727386147.648133]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727386147.649008]:  < Status: Arm lowering >
# [INFO] [1727386161.714921]:  < Status: Arm lowered >
# [INFO] [1727386161.716171]: ----------- Manager Loop END -----------
# [INFO] [1727386161.750278]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727386161.751029]:  < Status: Scanning >
# [INFO] [1727386161.751779]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=9.81e+05)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 13
#      10     print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
#      12 while (m.status == SCANNING):
# ---> 13     rospy.sleep(2)
#      15 print(m.status)
#
# File /opt/ros/noetic/lib/python3/dist-packages/rospy/timer.py:134, in sleep(duration)
#     132         return
#     133     else:
# --> 134         rospy.rostime.wallsleep(duration)
#     135 else:
#     136     initial_rostime = rospy.rostime.get_rostime()
#
# File /opt/ros/noetic/lib/python3/dist-packages/rospy/rostime.py:277, in wallsleep(duration)
#     275         pass
#     276 else:
# --> 277     time.sleep(duration)
#
# KeyboardInterrupt:

# %%
if (m.status != SCANNING and
    m.status != ERROR):
    while ( m.status == ARRIVED_AT_SCAN_LOC or
            m.status == ARM_RETURNED):
            m.run_once()
    m.run_once()
    print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')

print(m.status)
# Out:
# [INFO] [1727384847.982615]: ----------- Manager Loop: adaptive -----------
# [INFO] [1727384847.983646]:  < Status: Navigating to scan loc >
# [INFO] [1727384847.991300]:  | Goal Sent to movebase...
# [INFO] [1727384861.692360]:  | Movebase Goal Reached, Backing up...
# [INFO] [1727384863.696717]:  < Status: Arrived at scan loc >
# [INFO] [1727384863.697979]: ----------- Manager Loop END -----------
# GPR Kernel: RBF(length_scale=100)
# Arrived at scan loc

# %%
for i in range(0,4):
    if (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()

# %%
m.show()
# Out:
# [INFO] [1727383606.304002]: Sampled at [34, 6] with value = 0.0
# [INFO] [1727383606.305311]: Adaptive Norm Range: 0.2014

# %%
sampled = [[m.adaptiveROS.sampled[0][1], m.adaptiveROS.sampled[0][0]]]
# sampled = m.adaptiveROS.sampled
print(sampled)
m.adaptiveROS.gp.fit(sampled, 
                     m.adaptiveROS.sampled_val) #todo: Should we re-init self.gp?

nextScanLoc = m.adaptiveROS.predict(True)

# %%
nav_goal_map = m.conversion.grid2map(nextScanLoc[0], nextScanLoc[1])
nav_goal_gps = m.conversion.map2gps(nav_goal_map[0], nav_goal_map[1])
        
m.send_location_to_GUI(nav_goal_gps[0], nav_goal_gps[1])

# %%
import pickle

# %%
for i in range(0,20):
    if (m.status != SCANNING and
        m.status != ERROR):
        m.run_once()
        input()

# %%
with open('nrec_sep_13_adaptiveROS.pkl', 'wb') as file:
    pickle.dump(m.adaptiveROS, file)

# %%
with open('nrec_sep_13_transformer_variables.pkl', 'wb') as file:
    pickle.dump(member_vars, file)

# %%
member_vars.pop('adaptiveROS')

# %%
member_vars['tran

# %%
for i in range(0,20):
    if (m.status != SCANNING and
        m.status != ERROR):
        m.run_once()
        input()

# %%
m.show()
