# %% [markdown]
# # Params
# GaussianProcessRegressor(kernel=self.kernel, alpha=0.2, n_restarts_optimizer=50)
# algorithm_total_samples = 16
# RBF(length_scale=100, length_scale_bounds=(5, 1e06)
#         self.max_dist = max(3+self.min_dist, 2*(self.path_len / self.total_number) * self.orginal_max_dist)
# Dont use abs in bin_entropy

# %%
# %load_ext autoreload
# %autoreload 2
    
from manager import * 
import rosnode
import time
from env_utils.algo_constants import *

# %%
if '/manager' in rosnode.get_node_names():
    # print("Manager is running")
    rosnode.kill_nodes(['manager'])
    time.sleep(1)

m = Manager(skip_checks=False, 
            debug_flag=True) 
            # fake_hardware_flags=[FAKE_ARM, FAKE_PXRF])
# m.fake_pxrf_values = [0.13, 0.2, 0.0, 0.5, 0.6, 0.05]
# m.fake_pxrf_values = [0.4, 0.2, 0.3, 0, 0.02, 0.5, 0.32, 0.0, 0.6, 0.0, 0.1, 0.0]
# Out:
# [WARN] [1728593153.553405]: Started PXRF
# [INFO] [1728593153.555208]:  < Status: Initialization >
# [INFO] [1728593153.590659]:  < Status: Waiting for GPS init >
# [INFO] [1728593153.591478]: Waiting for GPS Initialization...
# [INFO] [1728593154.593403]: GPS Full Navigation Achieved!
# [INFO] [1728593154.595502]:  < Status: Ready >
# [INFO] [1728593154.602626]:  | Algorithm Set to ADAPTIVE with number of samples = 16
# [INFO] [1728593154.603594]:  ----------- READY -----------
# [WARN] [1728593160.877667]: | Reset
# [INFO] [1728593160.940961]: ----------------
#  Boundary Points:
#  [(40.47224520033441, -79.96624172498849), (40.472197471355194, -79.96616246385672), (40.47230406818266, -79.9660747860222), (40.47235430129668, -79.96617397912644), (40.47224520033441, -79.96624172498849)]
# ----------------
# [INFO] [1728593160.942129]: Boundary type: 0 (gps)
# [INFO] [1728593161.687729]: Width: 15 m | 60 cells
# [INFO] [1728593161.689089]: Height: 18 m | : 72 cells
# [INFO] [1728593161.689937]: Start: (9.817118677776307, 7.690185466781259) m | (38, 29) cells
# [INFO] [1728593161.690742]: Boundary Offset (MAP): [[0.0, 5.219322676770389], [6.781099629239179, 0.0], [14.075032074935734, 11.919543413445354], [5.601031873840839, 17.39703272935003], [0.0, 5.219322676770389]]
# [INFO] [1728593161.691555]: Boundary Offset (GRID): [(0, 19), (26, 0), (55, 46), (21, 68), (0, 19)]
# len(x1): 72, len(x2): 60, len(x1x2): (4320, 2)
# [INFO] [1728593161.693927]: lengths of x1 | x2 | x1x2: 72 | 60 | (4320, 2)
# [INFO] [1728593161.705861]:  < Status: Received search area >
# [INFO] [1728593161.774860]:  | Inital Robot Location (GPS|Map|Grid): (40.47226638097685, -79.96612557550422) | (9.818564503570087, 7.685747225768864) | (38, 29)
# [INFO] [1728593163.279716]:  < Status: Arrived at scan loc >
# [INFO] [1728593252.133254]: PXRF Mean Value: 1.448444128036499
# [INFO] [1728593252.134357]:  < Status: Finished scan >
# [INFO] [1728593252.455507]: PXRF Mean Value: 1.448444128036499
# [INFO] [1728593252.456458]:  < Status: Finished scan >
# [INFO] [1728593397.063456]: PXRF Mean Value: 0.0
# [INFO] [1728593397.064553]:  < Status: Finished scan >
# [INFO] [1728593397.291808]: PXRF Mean Value: 0.0
# [INFO] [1728593397.292935]:  < Status: Finished scan >
# [INFO] [1728593503.126400]: PXRF Mean Value: 1.9172011613845825
# [INFO] [1728593503.127571]:  < Status: Finished scan >
# [INFO] [1728593503.288207]: PXRF Mean Value: 1.9172011613845825
# [INFO] [1728593503.289209]:  < Status: Finished scan >
# [INFO] [1728593626.279898]: PXRF Mean Value: 0.0
# [INFO] [1728593626.281194]:  < Status: Finished scan >
# [INFO] [1728593626.418269]: PXRF Mean Value: 0.0
# [INFO] [1728593626.419421]:  < Status: Finished scan >
# [INFO] [1728593722.144825]: PXRF Mean Value: 0.15615440905094147
# [INFO] [1728593722.146072]:  < Status: Finished scan >
# [INFO] [1728593722.252011]: PXRF Mean Value: 0.15615440905094147
# [INFO] [1728593722.252912]:  < Status: Finished scan >
# [INFO] [1728593812.707682]: PXRF Mean Value: 0.0
# [INFO] [1728593812.708807]:  < Status: Finished scan >
# [INFO] [1728593812.896277]: PXRF Mean Value: 0.0
# [INFO] [1728593812.897153]:  < Status: Finished scan >
# [INFO] [1728593986.249923]: PXRF Mean Value: 0.0
# [INFO] [1728593986.251111]:  < Status: Finished scan >
# [INFO] [1728593986.355495]: PXRF Mean Value: 0.0
# [INFO] [1728593986.356498]:  < Status: Finished scan >

# %%
if (m.status != SCANNING and
    m.status != ERROR):
    while ( m.status == ARRIVED_AT_SCAN_LOC or
            m.status == ARM_RETURNED):
            m.run_once()
    m.run_once()
    print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')

print(m.status)
# Out:
# [INFO] [1728591474.559173]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728591474.560619]:  < Status: Arm lowering >
# [INFO] [1728591488.621289]:  < Status: Arm lowered >
# [INFO] [1728591488.622391]: ----------- Manager Loop END -----------
# [INFO] [1728591488.623920]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728591488.624876]:  < Status: Scanning >
# [INFO] [1728591488.625753]: ----------- Manager Loop END -----------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 7
#       5             m.run_once()
#       6     m.run_once()
# ----> 7     print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
#       9 print(m.status)
#
# AttributeError: 'GaussianProcessRegressor' object has no attribute 'kernel_'

# %%
for i in range(0,5):
    # print(f" ----- PATH LENGTH: {m.adaptiveROS.path_len} -----")
    
    while (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()
        # print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
    
    while (m.status == SCANNING):
        rospy.sleep(2)
        
    print(m.status)
# Out:
# [INFO] [1728593281.841077]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593281.841925]:  < Status: Running search algo >
# [INFO] [1728593281.908087]:  | Updating GPR with value=1.448444128036499 at (GPS|Map|Grid): (40.47226888480698, -79.96611442662577) | (10.758082693908364, 7.978542317636311) | (42, 30)
# ---------
# [INFO] [1728593282.740326]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47227926009506, -79.96611586484717) | (10.625, 9.125) | [42, 36]
# [INFO] [1728593282.794092]:  < Status: Received next scan loc >
# [INFO] [1728593282.795226]: ----------- Manager Loop END -----------
# [INFO] [1728593282.796850]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593282.797761]:  < Status: Navigating to scan loc >
# [INFO] [1728593282.805457]:  | Goal Sent to movebase...
# [INFO] [1728593332.706533]:  | Movebase Goal Reached, Backing up...
# [INFO] [1728593334.210667]:  < Status: Arrived at scan loc >
# [INFO] [1728593334.245005]: ----------- Manager Loop END -----------
# [INFO] [1728593334.246747]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593334.247767]:  < Status: Arm lowering >
# [INFO] [1728593348.301524]:  < Status: Arm lowered >
# [INFO] [1728593348.302798]: ----------- Manager Loop END -----------
# [INFO] [1728593348.304442]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593348.305321]:  < Status: Scanning >
# [INFO] [1728593348.306268]: ----------- Manager Loop END -----------
# Finished scan
# [INFO] [1728593398.355421]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593398.356438]:  < Status: Arm returning >
# [INFO] [1728593407.900412]:  < Status: Arm returned >
# [INFO] [1728593407.901481]: ----------- Manager Loop END -----------
# [INFO] [1728593407.902858]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593407.903682]:  < Status: Running search algo >
# [INFO] [1728593407.975568]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.4722803460975, -79.96612994757929) | (9.429781694547273, 9.231564826332033) | (36, 35)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 5.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1728593408.809090]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47226344404659, -79.96611020919245) | (11.125, 7.375) | [44, 29]
# [INFO] [1728593408.850840]:  < Status: Received next scan loc >
# [INFO] [1728593408.851834]: ----------- Manager Loop END -----------
# [INFO] [1728593408.853372]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593408.854168]:  < Status: Navigating to scan loc >
# [INFO] [1728593408.861456]:  | Goal Sent to movebase...
# [INFO] [1728593439.012787]:  | Movebase Goal Reached, Backing up...
# [INFO] [1728593440.516807]:  < Status: Arrived at scan loc >
# [INFO] [1728593440.517993]: ----------- Manager Loop END -----------
# [INFO] [1728593440.519462]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593440.520327]:  < Status: Arm lowering >
# [INFO] [1728593454.590922]:  < Status: Arm lowered >
# [INFO] [1728593454.592185]: ----------- Manager Loop END -----------
# [INFO] [1728593454.593579]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593454.594417]:  < Status: Scanning >
# [INFO] [1728593454.595313]: ----------- Manager Loop END -----------
# Finished scan
# [INFO] [1728593504.643398]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593504.644497]:  < Status: Arm returning >
# [INFO] [1728593514.211621]:  < Status: Arm returned >
# [INFO] [1728593514.212770]: ----------- Manager Loop END -----------
# [INFO] [1728593514.214407]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593514.215425]:  < Status: Running search algo >
# [INFO] [1728593514.282628]:  | Updating GPR with value=1.9172011613845825 at (GPS|Map|Grid): (40.47226467842732, -79.96611185376238) | (10.981125199352391, 7.513376880437136) | (42, 29)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 5.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1728593515.071266]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47225226368664, -79.96611922805127) | (10.375, 6.125) | [41, 24]
# [INFO] [1728593515.122639]:  < Status: Received next scan loc >
# [INFO] [1728593515.123669]: ----------- Manager Loop END -----------
# [INFO] [1728593515.125252]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593515.126332]:  < Status: Navigating to scan loc >
# [INFO] [1728593515.133806]:  | Goal Sent to movebase...
# [INFO] [1728593562.534916]:  | Movebase Goal Reached, Backing up...
# [INFO] [1728593564.039320]:  < Status: Arrived at scan loc >
# [INFO] [1728593564.040406]: ----------- Manager Loop END -----------
# [INFO] [1728593564.042119]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593564.043293]:  < Status: Arm lowering >
# [INFO] [1728593578.098547]:  < Status: Arm lowered >
# [INFO] [1728593578.099735]: ----------- Manager Loop END -----------
# [INFO] [1728593578.101162]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593578.102088]:  < Status: Scanning >
# [INFO] [1728593578.103051]: ----------- Manager Loop END -----------
# Finished scan
# [INFO] [1728593628.145184]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593628.146386]:  < Status: Arm returning >
# [INFO] [1728593637.672071]:  < Status: Arm returned >
# [INFO] [1728593637.673084]: ----------- Manager Loop END -----------
# [INFO] [1728593637.674484]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593637.675318]:  < Status: Running search algo >
# [INFO] [1728593637.738095]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.47226522491368, -79.96612783055211) | (9.627633972442709, 7.554641506634653) | (37, 29)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 5.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1728593638.667133]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.472270146986524, -79.96610420813185) | (11.625, 8.125) | [46, 32]
# [INFO] [1728593638.718726]:  < Status: Received next scan loc >
# [INFO] [1728593638.719560]: ----------- Manager Loop END -----------
# [INFO] [1728593638.720681]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593638.721346]:  < Status: Navigating to scan loc >
# [INFO] [1728593638.728439]:  | Goal Sent to movebase...
# [INFO] [1728593658.529355]:  | Movebase Goal Reached, Backing up...
# [INFO] [1728593660.033626]:  < Status: Arrived at scan loc >
# [INFO] [1728593660.034706]: ----------- Manager Loop END -----------
# [INFO] [1728593660.036551]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593660.037479]:  < Status: Arm lowering >
# [INFO] [1728593674.098891]:  < Status: Arm lowered >
# [INFO] [1728593674.100040]: ----------- Manager Loop END -----------
# [INFO] [1728593674.101491]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593674.102363]:  < Status: Scanning >
# [INFO] [1728593674.103105]: ----------- Manager Loop END -----------
# Finished scan
# [INFO] [1728593722.147601]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593722.148632]:  < Status: Arm returning >
# [INFO] [1728593731.684426]:  < Status: Arm returned >
# [INFO] [1728593731.685408]: ----------- Manager Loop END -----------
# [INFO] [1728593731.686800]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593731.687621]:  < Status: Running search algo >
# [INFO] [1728593731.750991]:  | Updating GPR with value=0.15615440905094147 at (GPS|Map|Grid): (40.472268204779326, -79.9661044829523) | (11.607629885198548, 7.907696886919439) | (45, 30)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 5.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1728593732.568154]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47225226368664, -79.96611922805127) | (10.375, 6.125) | [41, 24]
# [INFO] [1728593732.671983]:  < Status: Received next scan loc >
# [INFO] [1728593732.673043]: ----------- Manager Loop END -----------
# [INFO] [1728593732.674572]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593732.675498]:  < Status: Navigating to scan loc >
# [INFO] [1728593732.682933]:  | Goal Sent to movebase...
# [INFO] [1728593748.834027]:  | Movebase Goal Reached, Backing up...
# [INFO] [1728593750.338084]:  < Status: Arrived at scan loc >
# [INFO] [1728593750.339135]: ----------- Manager Loop END -----------
# [INFO] [1728593750.340663]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593750.341506]:  < Status: Arm lowering >
# [INFO] [1728593764.400503]:  < Status: Arm lowered >
# [INFO] [1728593764.401728]: ----------- Manager Loop END -----------
# [INFO] [1728593764.403249]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593764.404237]:  < Status: Scanning >
# [INFO] [1728593764.405206]: ----------- Manager Loop END -----------
# Finished scan

# %%
for i in range(0,10):
    # print(f" ----- PATH LENGTH: {m.adaptiveROS.path_len} -----")
    
    while (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()
        # print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
    
    while (m.status == SCANNING):
        rospy.sleep(2)
        
    print(m.status)
# Out:
# [INFO] [1728593871.024453]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593871.025436]:  < Status: Arm returning >
# [INFO] [1728593880.591416]:  < Status: Arm returned >
# [INFO] [1728593880.592404]: ----------- Manager Loop END -----------
# [INFO] [1728593880.593943]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593880.594903]:  < Status: Running search algo >
# [INFO] [1728593880.664999]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.472252106466655, -79.96611363540534) | (10.847346444730647, 6.113133841194212) | (42, 23)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 5.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1728593881.609080]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47221461445552, -79.96619058444224) | (4.375, 1.875) | [17, 7]
# [INFO] [1728593881.662442]:  < Status: Received next scan loc >
# [INFO] [1728593881.663462]: ----------- Manager Loop END -----------
# [INFO] [1728593881.665066]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593881.665993]:  < Status: Navigating to scan loc >
# [INFO] [1728593881.673767]:  | Goal Sent to movebase...
# [INFO] [1728593922.525051]:  | Movebase Goal Reached, Backing up...
# [INFO] [1728593924.029008]:  < Status: Arrived at scan loc >
# [INFO] [1728593924.030158]: ----------- Manager Loop END -----------
# [INFO] [1728593924.031712]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593924.032614]:  < Status: Arm lowering >
# [INFO] [1728593938.092473]:  < Status: Arm lowered >
# [INFO] [1728593938.093621]: ----------- Manager Loop END -----------
# [INFO] [1728593938.095122]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593938.096061]:  < Status: Scanning >
# [INFO] [1728593938.097015]: ----------- Manager Loop END -----------
# Finished scan
# [INFO] [1728593988.143359]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593988.144445]:  < Status: Arm returning >
# [INFO] [1728593997.677851]:  < Status: Arm returned >
# [INFO] [1728593997.679017]: ----------- Manager Loop END -----------
# [INFO] [1728593997.680544]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593997.681566]:  < Status: Running search algo >
# [INFO] [1728593997.749887]:  | Updating GPR with value=0.0 at (GPS|Map|Grid): (40.4722205743144, -79.96618181867633) | (5.110334012657404, 2.5452610291540623) | (19, 9)
# /home/patrick/.local/lib/python3.8/site-packages/sklearn/gaussian_process/kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 5.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ---------
# [INFO] [1728593998.684536]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.47227793138429, -79.96621910457644) | (1.875, 8.875) | [7, 35]
# [INFO] [1728593998.729674]:  < Status: Received next scan loc >
# [INFO] [1728593998.730680]: ----------- Manager Loop END -----------
# [INFO] [1728593998.732016]: ----------- Manager Loop: adaptive -----------
# [INFO] [1728593998.732872]:  < Status: Navigating to scan loc >
# [INFO] [1728593998.740106]:  | Goal Sent to movebase...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 9
#       6     while ( m.status == ARRIVED_AT_SCAN_LOC or
#       7             m.status == ARM_RETURNED):
#       8             m.run_once()
# ----> 9     m.run_once()
#      10     # print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
#      12 while (m.status == SCANNING):
#
# File ~/catkin_ws/src/environmental_robot/autonomy_manager/src/manager.py:201, in Manager.run_once(self)
#     199         self.run_grid_algo()
#     200 elif self.status == RECEIVED_NEXT_SCAN_LOC:
# --> 201     self.navigate_to_scan_loc()
#     202 elif self.status == ARRIVED_AT_SCAN_LOC:
#     203     if self.fake_hardware_mode:
#
# File ~/catkin_ws/src/environmental_robot/autonomy_manager/src/manager.py:477, in Manager.navigate_to_scan_loc(self)
#     475 self.update_status(NAVIGATION_TO_SCAN_LOC)
#     476 # self.navigation(self.nextScanLoc[0],self.nextScanLoc[1])
# --> 477 self.publish_move_base_goal(self.nav_goal_gps[0], self.nav_goal_gps[1])
#
# File ~/catkin_ws/src/environmental_robot/autonomy_manager/src/manager.py:541, in Manager.publish_move_base_goal(self, lat, lon)
#     539 self.mb_client.send_goal(goal)
#     540 rospy.loginfo(" | Goal Sent to movebase...")
# --> 541 wait = self.mb_client.wait_for_result()
#     542 rospy.loginfo(" | Movebase Goal Reached, Backing up...")
#     544 # Backup
#
# File /opt/ros/noetic/lib/python3/dist-packages/actionlib/simple_action_client.py:143, in SimpleActionClient.wait_for_result(self, timeout)
#     140         if time_left > loop_period or timeout == rospy.Duration():
#     141             time_left = loop_period
# --> 143         self.done_condition.wait(time_left.to_sec())
#     145 return self.simple_state == SimpleGoalState.DONE
#
# File /usr/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
if (m.status != SCANNING and
    m.status != ERROR):
    while ( m.status == ARRIVED_AT_SCAN_LOC or
            m.status == ARM_RETURNED):
            m.run_once()
    m.run_once()
    print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')

print(m.status)

# %%
for i in range(0,4):
    if (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()

# %%
m.show()

# %%
sampled = [[m.adaptiveROS.sampled[0][1], m.adaptiveROS.sampled[0][0]]]
# sampled = m.adaptiveROS.sampled
print(sampled)
m.adaptiveROS.gp.fit(sampled, 
                     m.adaptiveROS.sampled_val) #todo: Should we re-init self.gp?

nextScanLoc = m.adaptiveROS.predict(True)

# %%
nav_goal_map = m.conversion.grid2map(nextScanLoc[0], nextScanLoc[1])
nav_goal_gps = m.conversion.map2gps(nav_goal_map[0], nav_goal_map[1])
        
m.send_location_to_GUI(nav_goal_gps[0], nav_goal_gps[1])

# %%
import pickle

# %%
for i in range(0,20):
    if (m.status != SCANNING and
        m.status != ERROR):
        m.run_once()
        input()

# %%
with open('nrec_sep_13_adaptiveROS.pkl', 'wb') as file:
    pickle.dump(m.adaptiveROS, file)

# %%
with open('nrec_sep_13_transformer_variables.pkl', 'wb') as file:
    pickle.dump(member_vars, file)

# %%
member_vars.pop('adaptiveROS')

# %%
member_vars['tran

# %%
for i in range(0,20):
    if (m.status != SCANNING and
        m.status != ERROR):
        m.run_once()
        input()

# %%
m.show()
