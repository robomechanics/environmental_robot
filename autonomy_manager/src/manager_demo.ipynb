# %% [markdown]
# # Params
# GaussianProcessRegressor(kernel=self.kernel, alpha=0.2, n_restarts_optimizer=50)
# algorithm_total_samples = 16
# RBF(length_scale=100, length_scale_bounds=(5, 1e06)
#         self.max_dist = max(3+self.min_dist, 2*(self.path_len / self.total_number) * self.orginal_max_dist)
# - self.bin_entropy = (3 + normalization(self.mu)) + (self.beta * self.std_var)
# - self.max_dist = self.orginal_max_dist

# %%
# %load_ext autoreload
# %autoreload 2
    
from manager import * 
import rosnode
import time
from env_utils.algo_constants import *

# %%
if '/manager' in rosnode.get_node_names():
    # print("Manager is running")
    rosnode.kill_nodes(['manager'])
    time.sleep(1)

# m = Manager(skip_checks=False, 
#             debug_flag=True) 


m = Manager(skip_checks=False, 
            debug_flag=True,
            fake_hardware_flags=[FAKE_ARM, FAKE_PXRF],
            fake_pxrf_values = [0.13, 0.2, 0.0, 0.5, 0.6, 0.05])
# m.fake_pxrf_values = [0.4, 0.2, 0.3, 0, 0.02, 0.5, 0.32, 0.0, 0.6, 0.0, 0.1, 0.0]
# Out:
# [INFO] [1730169803.866688]:  < Status: Initialization >
# [INFO] [1730169803.910213]:  < Status: Waiting for GPS init >
# [INFO] [1730169803.910998]: Waiting for GPS Initialization...
# [INFO] [1730169804.913880]: GPS Full Navigation Achieved!
# [INFO] [1730169804.920797]:  < Status: Ready >
# [INFO] [1730169804.941882]:  | Algorithm Set to ADAPTIVE with number of samples = 16
# [INFO] [1730169804.943733]:  ----------- READY -----------
# [WARN] [1730169804.923931]: >>> USING FAKE HARDWARE <<<<
# [WARN] [1730169804.926340]: Fake Hardware Flags: ['fake_arm', 'fake_pxrf']
# [WARN] [1730169813.371449]: | Reset
# [INFO] [1730169813.401366]: ----------------
#  Boundary Points:
#  [(40.440187235706084, -79.94589432133836), (40.44016903538904, -79.94578998760997), (40.440137267682324, -79.94579190059557), (40.44009902290554, -79.94580719808918), (40.44011592229546, -79.94592301813978), (40.440187235706084, -79.94589432133836)]
# ----------------
# [INFO] [1730169813.402837]: Boundary type: 0 (gps)
# [INFO] [1730169814.258476]: Width: 12 m | 48 cells
# [INFO] [1730169814.259506]: Height: 10 m | : 40 cells
# [INFO] [1730169814.260289]: Start: (244582.3682460602, -4477139.315144943) m | (978328, 0) cells
# [INFO] [1730169814.261059]: Boundary Offset (MAP): [[2.339341029757634, 9.703579043969512], [11.212142018717714, 7.788927477784455], [11.091989270527847, 4.260721312835813], [9.845258057001047, 0.0], [0.0, 1.7586216740310192], [2.339341029757634, 9.703579043969512]]
# [INFO] [1730169814.261776]: Boundary Offset (GRID): [(8, 37), (43, 30), (43, 16), (38, 0), (0, 6), (8, 37)]
# Adaptive -> len(x1): 40, len(x2): 48, len(x1x2): (1920, 2)
# [INFO] [1730169814.263389]: lengths of x1 | x2 | x1x2: 40 | 48 | (1920, 2)
# [INFO] [1730169814.264272]:  < Status: Received search area >
# [INFO] [1730169814.323738]:  | Inital Robot Location (GPS|Map|Grid): (0.0, 0.0) | (244582.3682460602, -4477139.315144943) | (978328, 0)
# [INFO] [1730169814.328228]:  < Status: Arrived at scan loc >
# [WARN] [1730169814.324907]:  | RECORDED Robot Pose before Backup: 40.44016903538904, -79.94578998760997

# %%
if (m.status != SCANNING and
    m.status != ERROR):
    while ( m.status == ARRIVED_AT_SCAN_LOC or
            m.status == ARM_RETURNED):
            m.run_once()
    m.run_once()
    print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')

print(m.status)

# %%
for i in range(0,1):
    # print(f" ----- PATH LENGTH: {m.adaptiveROS.path_len} -----")

    while (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()
        # print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
    
    while (m.status == SCANNING):
        rospy.sleep(2)
        
    print(m.status)
# Out:
#   Cell In[8], line 3
#     PolyLineROINoHover python
#                        ^
# SyntaxError: invalid syntax

# %%
m.run_once()
# Out:
# [INFO] [1730170693.481412]: ----------- Manager Loop: adaptive -----------
# [INFO] [1730170693.482331]:  < Status: Running search algo >
# [INFO] [1730170693.546017]:  | Updating GPR with value=0.6 at (GPS|Map|Grid): (0.0, 0.0) | (244582.3682460602, -4477139.315144943) | (978328, 0)
# ---------
# [INFO] [1730170694.146623]:  | Sending Adaptive Algorithm Location (GPS|Map|Grid): (40.44016526251202, -1.9457851785967268) | (np.float64(11.625), np.float64(7.375)) | [np.int64(46), np.int64(29)]
# [INFO] [1730170694.150205]:  < Status: Received next scan loc >
# [INFO] [1730170694.150776]: ----------- Manager Loop END -----------
# [WARN] [1730170694.149268]: Sending location to GUI failed

# %%
m.

# %%
# m.status = FINISHED_SCAN
m.run_once()


for i in range(0,10):
    # print(f" ----- PATH LENGTH: {m.adaptiveROS.path_len} -----")
    
    while (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()
        # print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')
    
    while (m.status == SCANNING):
        rospy.sleep(2)
        
    print(m.status)

# %%
if (m.status != SCANNING and
    m.status != ERROR):
    while ( m.status == ARRIVED_AT_SCAN_LOC or
            m.status == ARM_RETURNED):
            m.run_once()
    m.run_once()
    print(f'GPR Kernel: {m.adaptiveROS.gp.kernel_}')

print(m.status)

# %%
for i in range(0,4):
    if (m.status != SCANNING and
        m.status != ERROR):
        while ( m.status == ARRIVED_AT_SCAN_LOC or
                m.status == ARM_RETURNED):
                m.run_once()
        m.run_once()

# %%
m.show()

# %%
sampled = [[m.adaptiveROS.sampled[0][1], m.adaptiveROS.sampled[0][0]]]
# sampled = m.adaptiveROS.sampled
print(sampled)
m.adaptiveROS.gp.fit(sampled, 
                     m.adaptiveROS.sampled_val) #todo: Should we re-init self.gp?

nextScanLoc = m.adaptiveROS.predict(True)

# %%
nav_goal_map = m.conversion.grid2map(nextScanLoc[0], nextScanLoc[1])
nav_goal_gps = m.conversion.map2gps(nav_goal_map[0], nav_goal_map[1])
        
m.send_location_to_GUI(nav_goal_gps[0], nav_goal_gps[1])

# %%
import pickle

# %%
for i in range(0,20):
    if (m.status != SCANNING and
        m.status != ERROR):
        m.run_once()
        input()

# %%
with open('nrec_sep_13_adaptiveROS.pkl', 'wb') as file:
    pickle.dump(m.adaptiveROS, file)

# %%
with open('nrec_sep_13_transformer_variables.pkl', 'wb') as file:
    pickle.dump(member_vars, file)

# %%
member_vars.pop('adaptiveROS')

# %%
member_vars['tran

# %%
for i in range(0,20):
    if (m.status != SCANNING and
        m.status != ERROR):
        m.run_once()
        input()

# %%
m.show()
